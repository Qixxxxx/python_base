# %% [markdown]
# # Python3 中有 7种标准数据类型
#
# ### Number（数字，包括整型int、浮点数float、复数complex）
# ### String（字符串）
# ### bool（布尔类型，bool 是 int 的子类）
# ### List（列表）
# ### Tuple（元组）
# ### Set（集合）
# ### Dictionary（字典）

# %% [markdown]
# ## 按是否可变，可以分为以下两类：
# ### 不可变数据（4 个）：Number（数字）、String（字符串）、bool（布尔）、Tuple（元组）
# ### 可变数据（3 个）：List（列表）、Dictionary（字典）、Set（集合）

# %% [markdown]
# ## Number（数字，包括整型int、浮点数float、复数complex）

# %%
# 使用 type()函数确定数据类型
print(type(1))
print(type(-1.1))
print(type(1+1j))
print(type(False))

# 用 isinstance()函数 来判断是否属于某类
print(isinstance(1, int))
print(isinstance(True, int))  # bool是int的子类
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# True
# True

# %% [markdown]
# ### 数值计算

# %%
# 加法
print(5 + 4)
# 减法
print(4.3 - 2)
# 乘法
print(3 * 7)
# 除法，得到一个浮点数
print(2 / 4)
# 整除，得到一个整数
print(2 // 4)
# 取余
print(17 % 3)
# 乘方
print(2 ** 5)
# Out:
# 9
# 2.3
# 21
# 0.5
# 0
# 2
# 32

# %% [markdown]
# ## String（字符串）
# ### Python 中的字符串用单引号 ' 或双引号 " 括起来，同时使用反斜杠 \ 转义特殊字符。

# %%
# 用单引号或者双引号包住的文本为字符串
print('123') 
print("123") 

# 字符串内部既包含 ' 又包含 " 怎么办？可以用转义字符反斜线来标识
print("I\'m \'OK\'!") # 注意：斜线是键盘上？那个，反斜线是回车上面那个

# 转义字符\可以转义很多字符，比如\n表示换行，\t表示制表符
print('hello, \n world!')

# 字符\本身也要转义，所以\\表示的字符就是\
print('hello, \\n world!')

# 用r''表示''内部的字符串默认不转义
print(r'hello, \n world!')
# Out:
# 123
# 123
# I'm 'OK'!
# hello,
#  world!
# hello, \n world!
# hello, \n world!

# %% [markdown]
# ## bool（布尔类型）
# ### 布尔类型只有两个值：True 和 False
# ### 布尔类型可以用来控制程序的流程，比如判断某个条件是否成立，或者在某个条件满足时执行某段代码
# ### bool 是 int 的子类，因此布尔值可以被看作整数来使用，其中 True 等价于 1，False 等价于 0

# %%
# 布尔类型的值和类型
a = True
b = False
print(type(a))  # <class 'bool'>
print(type(b))  # <class 'bool'>

# 布尔类型的整数表现
print(int(True))   # 1
print(int(False))  # 0

# 布尔逻辑运算
print(True and False)  # 与  运算
print(True or False)   # 或  运算
print(not True)        # 非  运算

# 布尔比较运算
print(5 > 3)   # True
print(2 == 2)  # True
print(7 < 4)   # False

# 布尔值在控制流中的应用
if True:
    print("This will always print")

if not False:
    print("This will also always print")

x = 10
if x:
    print("x 是非零值，在布尔上下文中为 True")
# Out:
# <class 'bool'>
# <class 'bool'>
# 1
# 0
# False
# True
# False
# True
# True
# False
# This will always print
# This will also always print
# x 是非零值，在布尔上下文中为 True

# %% [markdown]
# ## List（列表）
# ### List（列表）是 Python 中使用最频繁的数据类型。列表可以完成大多数集合类的数据结构实现。列表中元素的类型可以不相同，它支持数字、字符串，甚至可以包含列表（即嵌套列表）。列表写在方括号 [] 之间，用逗号分隔开的元素列表。

# %%
empty_list = [] # 创建空列表
my_list = ['abcd', 786, 2.23, 'runoob', 70.2]  # 避免使用 list 作为变量名，会覆盖内置类型
tinylist = [123, 'runoob']
print(type(empty_list))
print(my_list)
print(my_list[0])          # 根据索引访问指定位置元素
print(my_list[1:3])        # 切片
print(my_list[2:])         # 切片，打印从索引 2 开始到末尾的所有元素：[2.23, 'runoob', 70.2]
print(tinylist * 2)        # 重复
print(my_list + tinylist)  # 拼接两个列表
# Out:
# <class 'list'>
# ['abcd', 786, 2.23, 'runoob', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'runoob', 70.2]
# [123, 'runoob', 123, 'runoob']
# ['abcd', 786, 2.23, 'runoob', 70.2, 123, 'runoob']

# %% [markdown]
# ## Tuple（元组）
# ### 元组（tuple）与列表类似，最大不同之处在于元组的元素不能修改。元组写在小括号 () 里。

# %%
empty_tuple = () # 创建空元组
my_tuple = ('abcd', 786, 2.23, 'runoob', 70.2)  # 避免使用 tuple 作为变量名
tinytuple = (123, 'runoob')
print(type(empty_tuple))
print(my_tuple)
print(my_tuple[0])
print(my_tuple[1:3])
print(my_tuple[2:])
print(tinytuple * 2)
print(my_tuple + tinytuple)
# Out:
# <class 'tuple'>
# ('abcd', 786, 2.23, 'runoob', 70.2)
# abcd
# (786, 2.23)
# (2.23, 'runoob', 70.2)
# (123, 'runoob', 123, 'runoob')
# ('abcd', 786, 2.23, 'runoob', 70.2, 123, 'runoob')

# %% [markdown]
# ## Set（集合）
# ### Python 中的集合（Set）是一种无序、可变的数据类型，用于存储唯一的元素。集合中的元素不会重复，并且可以进行交集、并集、差集等常见的集合操作。

# %%
empty_set = set() # 创建空集合

sites = {'Google', 'Taobao', 'Runoob', 'Facebook', 'Zhihu', 'Baidu'}

print(sites)   # 输出集合（无序，重复元素会被自动去掉）

# 成员测试
if 'Runoob' in sites:
    print('Runoob 在集合中')
else:
    print('Runoob 不在集合中')

# set 可以进行集合运算
a = set('abracadabra')   # 字符串转为字符集合
b = set('alacazam')

print(a)           # a 中的唯一字符

print(a - b)       # a 和 b 的差集（在 a 中但不在 b 中）
print(a | b)       # a 和 b 的并集（在 a 或 b 中）
print(a & b)       # a 和 b 的交集（同时在 a 和 b 中）
print(a ^ b)       # a 和 b 的对称差集（在 a 或 b 中，但不同时存在）
# Out:
# {'Baidu', 'Runoob', 'Taobao', 'Facebook', 'Google', 'Zhihu'}
# Runoob 在集合中
# {'c', 'b', 'd', 'a', 'r'}
# {'d', 'b', 'r'}
# {'c', 'b', 'd', 'z', 'a', 'm', 'r', 'l'}
# {'c', 'a'}
# {'l', 'd', 'z', 'b', 'm', 'r'}

# %% [markdown]
# ## Dictionary（字典）
# ### 字典（dictionary）是 Python 中另一个非常有用的内置数据类型。字典是一种映射类型，用 {} 标识，它是一个 键(key) : 值(value) 的集合。键(key) 必须使用不可变类型，且在同一个字典中键必须是唯一的。

# %%
empty_dict = {}  # 创建一个空字典
empty_dict['one'] = "1 - 菜鸟教程"
empty_dict[2]     = "2 - 菜鸟工具"

tinydict = {'name': 'runoob', 'code': 1, 'site': 'www.runoob.com'}

print(empty_dict['one'])       # 输出键为 'one' 的值
print(empty_dict[2])           # 输出键为 2 的值
print(tinydict)             # 输出完整的字典
print(tinydict.keys())      # 输出所有键
print(tinydict.values())    # 输出所有值
# Out:
# 1 - 菜鸟教程
# 2 - 菜鸟工具
# {'name': 'runoob', 'code': 1, 'site': 'www.runoob.com'}
# dict_keys(['name', 'code', 'site'])
# dict_values(['runoob', 1, 'www.runoob.com'])

# %% [markdown]
# ## bytes 类型
# ### 在 Python3 中，bytes 类型表示的是不可变的二进制序列（byte sequence）。与字符串类型不同的是，bytes 类型中的元素是整数值（0 到 255 之间的整数），而不是 Unicode 字符。
# ### bytes 类型通常用于处理二进制数据，比如图像文件、音频文件、视频文件等。在网络编程中，也经常使用 bytes 类型来传输二进制数据。
# ### 创建 bytes 对象最常见的方式是使用 b 前缀：

# %%
x = b"hello"           # 使用 b 前缀创建 bytes 对象
print(x)               # b'hello'
print(type(x))         # <class 'bytes'>
print(x[0])            # 104（'h' 的 ASCII 值，bytes 元素是整数）

x = bytes("hello", encoding="utf-8") #也可以使用 bytes() 函数将其他类型的对象转换为 bytes 类型，第二个参数指定编码方式
# Out:
# b'hello'
# <class 'bytes'>
# 104
